# %%
import pandas as pd
import numpy as np

# %%
districts = pd.read_csv('DistrictCorrespondingZips.csv')
districts.head()
# Out:
#   District  ZipCode
# 0       A1     2114
# 1      A15     2114
# 2       A7     2128
# 3       B2     2119
# 4       A7     2128

# %%
incomes = pd.read_csv('IncomeLevels.csv')
incomes.head()
# Out:
#    Zip Code Population Avg. Income/H/hold
# 0      2210        592        $86,918.00
# 1      2110      1,428        $79,085.00
# 2      2109      3,428        $78,254.00
# 3      2108      3,446        $71,199.00
# 4      2199      1,005        $65,313.00

# %%
weather = pd.read_csv('weather.csv')
weather.head()
# Out:
#        STATION           NAME  LATITUDE  LONGITUDE  ELEVATION        DATE  \
# 0  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  2015-01-01
# 1  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  2015-01-02
# 2  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  2015-01-03
# 3  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  2015-01-04
# 4  USW00014739  BOSTON, MA US   42.3606   -71.0097        3.7  2015-01-05
#
#     AWND AWND_ATTRIBUTES  PGTM PGTM_ATTRIBUTES  ...  WT04 WT04_ATTRIBUTES  \
# 0  14.32             ,,W   NaN             NaN  ...   NaN             NaN
# 1  12.75             ,,W   NaN             NaN  ...   NaN             NaN
# 2  10.29             ,,W   NaN             NaN  ...   1.0             ,,W
# 3   8.28             ,,W   NaN             NaN  ...   NaN             NaN
# 4  22.15             ,,W   NaN             NaN  ...   NaN             NaN
#
# ...

# %%
crime = pd.read_csv('crime.csv',encoding='latin1')
crime.head()
# Out:
# s:\python\3.7.7\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0      I182080058          2403  Disorderly Conduct
# 1      I182080053          3201       Property Lost
# 2      I182080052          2647               Other
# 3      I182080051           413  Aggravated Assault
# 4      I182080050          3122            Aircraft
#
#               OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0            DISTURBING THE PEACE      E18            495      NaN
# 1                 PROPERTY - LOST      D14            795      NaN
# 2       THREATS TO DO BODILY HARM       B2            329      NaN
# 3  ASSAULT - AGGRAVATED - BATTERY       A1             92      NaN
# 4              AIRCRAFT INCIDENTS       A7             36      NaN
#
# ...

# %%
crime['SHOOTING'] = crime['SHOOTING'].replace(np.nan, 'N')
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0      I182080058          2403  Disorderly Conduct
# 1      I182080053          3201       Property Lost
# 2      I182080052          2647               Other
# 3      I182080051           413  Aggravated Assault
# 4      I182080050          3122            Aircraft
#
#               OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0            DISTURBING THE PEACE      E18            495        N
# 1                 PROPERTY - LOST      D14            795        N
# 2       THREATS TO DO BODILY HARM       B2            329        N
# 3  ASSAULT - AGGRAVATED - BATTERY       A1             92        N
# 4              AIRCRAFT INCIDENTS       A7             36        N
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0  2018-10-03 20:13:00  2018     10   Wednesday    20    Part Two
# 1  2018-08-30 20:00:00  2018      8    Thursday    20  Part Three
# ...

# %%
weathercrime = pd.read_csv('WeatherCrime.csv')
weathercrime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP        OFFENSE_DESCRIPTION  \
# 0      I182080052          2647              Other  THREATS TO DO BODILY HARM
# 1      I182080052          2647              Other  THREATS TO DO BODILY HARM
# 2      I182080047          3301    Verbal Disputes             VERBAL DISPUTE
# 3      I182080047          3301    Verbal Disputes             VERBAL DISPUTE
# 4      I182080035          2647              Other  THREATS TO DO BODILY HARM
#
#   DISTRICT SHOOTING        DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0       B2       NO  10/03/2018  2018     10   Wednesday    19    Part Two
# 1       B2       NO  10/03/2018  2018     10   Wednesday    19    Part Two
# 2       B2       NO  10/03/2018  2018     10   Wednesday    19  Part Three
# 3       B2       NO  10/03/2018  2018     10   Wednesday    19  Part Three
# 4       B2       NO  10/03/2018  2018     10   Wednesday    19    Part Two
#
# ...
